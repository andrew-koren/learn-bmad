# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Pillbox
#
# Nothing too crazy here. I think we did this in Prof. Shylnov's class actually. Our pillbox is a cylinder with radius $a$ and length $h$. Combine Maxwell's equations
#
# $$
# \begin{align*}
#     \nabla^2 \vec E &= - \nabla \times \nabla \times \vec E
# \\  &= \nabla \times {\partial \vec B \over \partial t}
#      =  {\partial  \over \partial t} \left(\nabla \times \vec B\right)
# \\  &=  \mu_0 {\partial \vec J \over \partial t} + \mu_0 \epsilon_0 { \partial^2 E \over \partial t^2 }.
# \end{align*}
# $$
# No current in the cavity space, so this leaves us with
# $$
# \nabla^2 \vec E = { 1 \over c^2} { \partial^2 \vec E \over \partial t^2 }.
# $$
#
# Now I can copy/paste all my old notes! $\def\d#1#2{\frac{\partial #1}{\partial #2}}$
# In class we found the longitudinal accelerating field, which is a good start since it is the accelerating component. Apply the del operator in cylindrical coordinates:
#
# $$
# \begin{gathered}
#       \nabla
#     = \d{}{r} \hat r + {1 \over r} \d{}{\phi} \hat \phi + \d{}{z} \hat z
# \quad
# \\    \d{^2 \vec E}{t^2} \cdot \hat z
#     = c^2 \nabla^2 \vec E \cdot \hat z
# \\    \d{^2E_z}{t^2}
#     = c^2 \left( \d{^2 E_z}{r^2} + {1\over r} \d{E_z}{r} + {1 \over r^2} \d{^2E_z}{\phi^2} + \d{^2E_z}{z^2}\right),
# \end{gathered}
# $$
# and we assume the periodic solution
# $$
# \begin{gathered}
# \\  E_z = e^{\pm i \omega t} u(r,\phi,t),
# \\  \nabla^2 u + {\omega^2 \over c^2} u = 0
#     \quad \rightarrow \quad
#     {\omega \over c} = k,
# \\  \d{^2 u}{r^2} + {1\over r} \d{u}{r} + {1 \over r^2} \d{^2u}{\phi^2} + \d{^2u}{z^2} + k^2 u = 0.
# \end{gathered}
# $$
#
# The cavity boundary conditions really just boil down to the perfect conductor $\lambda_L=0$, alongside enforcing  $\nabla \cdot \vec E = 0$. I think these are all of them:
# $$
# \begin{gathered}
#     E_z(a,\phi,z,t)=0,
# \\  u  (a,\phi,z)=0,
# \\  u(0,\phi,z) \text{ finite},
# \\  u(r,\phi,z) = u(r,\phi+2\pi,z),
# \\  \d{E_z}{z} = 0, \quad z = 0,h.
# \end{gathered}
# $$
# Insert separable solution
# $$
# \begin{gathered}
#     E_z = e^{\pm i \omega t} R \Phi Z,
# \\    \frac{R'' + {1\over r}R'}{R}
#     + {1\over r^2} \underbrace{\frac{\Phi''}{\Phi}}_{-n^2}
#     + \underbrace{\frac{Z''}{Z}}_{-\mathscr K^2}
#     + k^2
#     = 0,
# \\  \Phi = A \cos (n \phi) + B \sin (n\phi),
# \\  Z = c_1 \cos(\mathscr K z) + c_2 \sin(\mathscr K z).
#     \\  \mathscr K h = \pi m,
# \\  Z = \cos \left( \pi m z \over h\right),
# \end{gathered}
# $$
# These come from the periodic and Neumann boundary conditions, as well as the nonzero $z=0$ term.
# $$
#     R'' + {1 \over r} R' + \left[k^2 - \mathscr K^2-{n^2\over r^2}\right] R = 0.
# $$
# To make this look more like a bessel differential equation, we use
# $$
#       \gamma_{m n}^2
#     = k^2 - \mathscr K^2
#     = {\omega_{mn}^2 \over c^2}
#     - \left( \pi m \over h \right)^2
#     > 0
# $$
# with the greater than relation required for real solutions. This gives us
# $$
# \begin{gathered}
# \\    R(r)
#     = A J_n (\gamma_{mn}r)
#     + B N_n (\gamma_{mn}r),
# \\  R(0) \text{ finite } \rightarrow B = 0,
# \\  \gamma_{mn} a = \alpha_{ns} \rightarrow J_n(\alpha_{ns})=0,
# \\  \gamma_{mn}^2 = \left( \alpha_{ns} \over a\right)^2,
# \\[0.25em]
#     \omega_{mns}^2 = \left( \alpha_{ns}c \over a \right)^2 + \left( \pi m c \over h \right)^2.
# \end{gathered}
# $$
# With this choice we have no electric field at the edges, $\text{TM}_{nsm}$
# - Azimuthal n
# - Radial s
# - Axial m
# $$
#       E_z(r, \phi,z,t)
#     = J_n \left( \alpha_{ns} r \over a \right)
#       \left[A \cos(n\phi) + B \sin(n\phi) \right]
#       \cos \left( \pi m z \over h \right)
#       e^{\pm i \omega_{nsm}t},
# $$
# where $A$, $B$, and the time dependence sign are determined by how the mode is excited (/initial conditions). Following the form in Peter Lane's dissertation, this is equivalent to
# $$
# \begin{gathered}
#       E_z(r, \phi,z,t)
#     = AJ_n \left( k_r r  \right)
#       \cos(n\phi + \delta)
#       e^{i\left(k_z z  - \omega_{nsm}t \right)},
# \\    k_r
#     = { \alpha_{ns} \over a},
# \quad
#       k_z
#     = {\pi m z \over h},
# \end{gathered}
# $$
# in the real plane. Technically, we can even throw the $\cos \phi$ term in the exponential too,
# $$
#       AE_z(r, \phi,z,t)
#     = J_n \left( k_r r  \right)
#       e^{i\left(k_z z  - \omega_{nsm}t + n\phi + \delta\right)},
# $$
# which isn't very pretty. For $\text{TM}_{010}$, this will always become
# $$
#       E_z(r, \phi,z,t)
#     = A J_0 \left( \alpha_{01} r \over a \right)
#       e^{\pm i \omega_{010}t}.
# $$
#
#
# To progress, we'll need to use $\nabla \times \vec B = {1 \over c} \d{\vec E}{t}$, but that curl would include $E_r$ and $E_\phi$. I'll take a tip from Peter Lane, which is to use $\nabla \times \vec E = - {i\omega \over c} \vec B$  since both fields oscillate at the same rate, then match up the expanded curls. Also note $B_z = 0 $ for TM.
#
# $$
# \begin{gathered}
#       (\nabla \times \vec E)\cdot \hat \phi
#     = {i \omega \over c} B_\phi
# \quad \longrightarrow \quad
#       \d{E_r}{z}
#     = \d{E_z}{r} + {i \omega \over c} B_\phi
#     ik
# \\
# \\    (\nabla \times \vec E)\cdot \hat r
#     = {i \omega \over c} B_r
# \end{gathered}
# $$

# %% [markdown]
# <!-- old
#
# We can extract $\vec B$ using
#
# $$
# % \begin{align*}
# \nabla \times \vec B = {1 \over c^2} {\partial \vec E \over \partial t}.
# % \end{align*}
# $$
#
# I think we are free to choose $B_z = 0$ since accelerators use the $\text{TM}$ mode, so we'll assume this to make things easier. This reduces the curl down to
#
# $$
# % \begin{gathered}
#       \nabla \times \vec B
#     = - \d{B_\phi}{z} \hat r
#     + \d{B_r}{z} \hat \phi,
# % \end{gathered}
# $$
#
# Having no $B_z$ term also allows us to solve for the other components of the electric field.
#
# $$
# \begin{gathered}
#       \left( \nabla \times \vec E\right)_z
#     = -\d{B_z}{t}
#     = 0,
# \\    \d{(r E_\phi)}{r} = \d{E_r}{\phi}
#
# \end{gathered}
#
# $$
# \begin{gathered}
#       \nabla \cdot \vec E
#     = {1 \over r} \d{r E_r}{dr} + {1 \over r} \d{E_\phi}{\phi} + \d{E_z}{z}
#     = 0,
# \\    \d{E_z}{z}
#     = - {1 \over r} \d{(r E_r)}{r} - {1 \over r} \d{E_\phi}{\phi}
# %     = - {2 \over r} \d{E_\phi}{\phi},
# % \\  \begin{align*}
# %       E_r
# %    &= \left(- {r \over 2}\right) \int
# %         \d{E_z}{z}
# %       d \phi
# % \\ &= \left(  {r \over 2} {\pi m \over h}\right) \int
# %         J_n \left( \alpha_{ns} r \over a \right)
# %         \left[A \cos(n\phi) + B \sin(n\phi) \right]
# %         \sin \left( \pi m z \over h \right)
# %         e^{\pm i \omega_{nsm}t}
# %       d \phi
# % \\ &= \left(  {r \over 2} {\pi m \over nh}\right)
# %         J_n \left( \alpha_{ns} r \over a \right)
# %         \left[A \sin(n\phi) - B \sin(n\phi) \right]
# %         \sin \left( \pi m z \over h \right)
# %         e^{\pm i \omega_{nsm}t}
#     % \end{align*}
# \end{gathered}
# $$
#
# $$ -->

# %% [markdown]
# ---
#
# 2. Longitudinal Dynamics.
#
# I got this one started in class using some code from my undergrad, although I'm not too sure about parameter values. These are basically equations of motion, with $\phi$ and $\Delta E$ instead of $x$ and $v$
#
# $$
# \begin{cases}
#     \phi_{n+1} = \phi_n + a_0 \Delta E_n
# \\  \Delta E_{n+1} = \Delta E_n + a_1 \left(\sin \phi_{n+1} - \sin{\phi_s} \right)
# \end{cases}
# $$
# where
# $$
# a_0 = { 2\pi h \eta \over \beta^2 E} \quad a_1 = eV
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np

def accelerator_EOM(phase, ΔE, params:list):
    a0, a1, phi_s = params
    dphase = a0*ΔE
    dE = a1*(np.sin(phase+dphase) - np.sin(phi_s))
    return dphase, dE

def accelerator_step(phase_0, ΔE_0, params:list):
    a0, a1, phi_s = params
    phase_1 = phase_0 + a0*ΔE_0
    ΔE_1 = ΔE_0 + a1*(np.sin(phase_1) - np.sin(phi_s))
    return phase_1, ΔE_1

params = [0.1, -0.1, 30/360*2*np.pi] # a0, a1, phi_s
linspace_phi = np.linspace(-2*np.pi, 2*np.pi, 30)
linspace_ΔE = np.linspace(-3, 3, 30)

phase, ΔE = np.meshgrid(linspace_phi, linspace_ΔE) 

def get_points(X, V, func, params):
    dx, dv =  np.zeros(X.shape), np.zeros(V.shape)

    xlim, ylim = X.shape
    for i in range(xlim):
        for j in range(ylim):
            xloc = X[i,j]
            vloc = V[i,j]
            dx[i,j], dv[i,j] = func(xloc, vloc, params)
    
    return(dx, dv)


def make_phase_space(X, V, dx, dv, axs=None):
    if axs is None:
        fig, axs = plt.subplots(1, 2, sharex=True, sharey=True)
        fig.set_figheight(4)
        fig.set_figwidth(12)
    axs[0].quiver(X,V,dx,dv)
    axs[0].set_xlabel(r"$\phi$")
    axs[0].set_ylabel(r"$\Delta E$")
    axs[1].streamplot(X,V,dx,dv)
    axs[1].set_xlabel(r"$\phi$")
    axs[1].set_ylabel(r"$\Delta E$")

dPhase, dΔE = get_points(phase, ΔE, accelerator_EOM, params)
make_phase_space(phase, ΔE, dPhase, dΔE)
plt.suptitle('One-Cavity-Hop Phase Space')
# Out:
# Text(0.5, 0.98, 'One-Cavity-Hop Phase Space')

# %% [markdown]
# we can also numerically compute and draw the separatrix. The formula in our lecture is
#
# $$
# \Delta E^2 + 2 {\beta^2 E \over 2\pi h \eta} eV \left( \cos \phi + \phi \sin \phi_s \right) = c_0
# $$
# With our unitless variables this becomes
# $$
# \Delta E^2 + {2a_1 \over a_0} \left( \cos \phi + \phi \sin \phi_s \right) = c_0
# $$
# By determining the location of the saddle point from our "EOM" we can easily draw the separatrix, which occurs when $\phi_{n+1} = \phi_{n},\ \Delta E_{n+1} = \Delta E_{n}$
# $$
# \begin{gathered}
#     0 = a_0 \Delta E_n
#     \rightarrow E_n = 0
# \\  0 = a_1 \left(\sin \phi_{n+1} - \sin \phi_s \right)
#     \rightarrow \phi_{n} = \phi_s,\ \phi_s + \pi
# \\
# \end{gathered}
# $$
# Since $\phi=\phi_s$ (modulo $2\pi$) is the stable point, we know $\phi_s + \pi$ will be the saddle point.
#
# Below, we compute $c_0$ from initial conditions, then draw the separatrix around the central stable point.
#
# $$
# \Delta E = \pm \sqrt{c_0 - {2a_1 \over a_0} \left( \cos \phi + \phi \sin \phi_s \right)}
# $$

# %%
from numpy import sin, cos, pi, sqrt

def get_c0(params, n=0):
    a0, a1, phi_s = params
    phi_unstable = pi-phi_s+2*pi*n
    return 2*a1/a0*(cos(phi_unstable) + phi_unstable*sin(phi_s))

def get_trajectories(params, c0 = None, n=0): # haven't checked what happens with no valid regions
    a0, a1, phi_s = params
    if c0 is None:
        c0 = get_c0(params, n=n)

    phi_traj = np.linspace(-2*pi, 2*pi, 10000)

    inside = c0-2*a1/a0*(cos(phi_traj)+phi_traj*sin(phi_s))
    valid = np.where(inside > 0)[0] # indicies of positive vals
    split_at = np.where(np.diff(valid) > 1)[0] + 1 # index discontinuities
    postive_regions = np.split(valid, split_at)

    valid_phi = [phi_traj[region] for region in postive_regions]
    valid_ΔE  = [sqrt(inside[region]) for region in postive_regions]

    return valid_phi, valid_ΔE

def plot_traj(params, ax, c0=None, n=0, color='red'):
    valid_phi, valid_ΔE = get_trajectories(params, c0, n)
    for phi_curve, ΔE_curve in zip(valid_phi, valid_ΔE):
        ax.plot(phi_curve, ΔE_curve, color = color)
        ax.plot(phi_curve,-ΔE_curve, color = color)

fig, axs = plt.subplots(1, 2, sharex=True, sharey=True)
fig.set_figheight(4)
fig.set_figwidth(12)

dPhase, dΔE = get_points(phase, ΔE, accelerator_EOM, params)
make_phase_space(phase, ΔE, dPhase, dΔE, axs=axs)

plot_traj(params, ax=axs[0])
plot_traj(params, ax=axs[1])

# %% [markdown]
# Note: I've got a plotting module on my device that helps with tick labeling.

# %%
from plotting import multiple_formatter

fig, axs = plt.subplots(1, 2, sharex=True, sharey=True)
fig.set_figheight(4)
fig.set_figwidth(12)

dPhase, dΔE = get_points(phase, ΔE, accelerator_EOM, params)
make_phase_space(phase, ΔE, dPhase, dΔE, axs=axs)

plot_traj(params, ax=axs[1])

for ax in axs:
    plot_traj(params, ax=ax)
    ax.xaxis.set_major_locator(plt.MultipleLocator(np.pi / 2))
    ax.xaxis.set_minor_locator(plt.MultipleLocator(np.pi / 12))
    ax.xaxis.set_major_formatter(plt.FuncFormatter(multiple_formatter()))

# %% [markdown]
# ---
#
# 3. Phase Space plotting
#
# Thanks to pytao, we have the option to choose Tao's built-in phase space plotting or use a python package with bmad's output. Particle tracking is heavily covered in all three of our manuals, which is a blessing and a curse. I'lll read through and report on what I find.
#
# Alongside tracking, I wonder if there's a way to do multi-turn tracking so we don't need to do `line = (500*cell)`

# %% [markdown]
# <!-- The basic `do enddo` bmad loop can easily make a long lattice, but I'm not sure if this is the best way to implement what we're trying to do. Even more absurd, we could use python to create a really long text file.
#
# ```bmad
# d: drift, l = 1
# cavity: lcavity, l = 0.2, voltage = 1e7, rf_frequency = 1e9, superimpose
# linac: line = (
#     do i = 1, 500
#       cavity
#     enddo
# )
# ``` -->
#
#
# Tutorial Chapter 17: Multipass describes how to reuse a line
#
# ```bmad
# linac: line[multipass] = (...)
# erl: line = (linac, linac)
# ...
# ```
#
# but this is more for ERLs or other weird systems, and doesn't make it easier to place 500 cavities.
#
# Bmad Chapter 6: Tracking:
#
# Most of this is for specifing the various numerical tracking methods. There is some space charge tracking, but nothing really useful for our purposes.
#
# Tutorial chapter 21 / Bmad Chapter 12 / Tao Section 10.7: Beam Initialization.
#
# The tutorial gives a pretty simple template for tracking. In the namespace, we can set up a particle distribution based off $\Delta x$ and $\Delta p$, and set the number of particles to be tracked / plotted. Then, plotting is done with `place r11 bunch_x_px` or similar. The prompt specifies a pencil beam, i.e. zero spread in $x/y$ but a spread in the longitudinal $z/p_z$.
#
# Tao Section 10.13.14: Phase Space Plotting.
#
# While the `bunch_<R1>_<R2>` plotting template makes it seem like we can only use phase space coordinates for plotting, the Tao manual further clarifies that time, energy, and action can also be plotted. It doesn't look like the phase $\phi$ is an option, so we'd need python to extract those terms for plotting. We should try playing around with `xphase` and `phase_space` templates as well.
#
# I also saw there was a way to do single-particle multi-turn tracking with `curve%data_source = multi_turn_orbit`, and specifying `curve%n_turn = 500`. There is also an example in the [bmad documentation](https://github.com/bmad-sim/bmad-ecosystem/tree/main/bmad-doc/tao_examples/multi_turn_orbit), but I realized it is only for plotting each of the 500 turns a single particle makes, not for multi-particle beam plotting.
#
#
# Tutorial Chapter 23 / Tao Chapter 9: Wave Analysis: Actually, this is for troubleshooting physical beamlines with real errors, a bit beyond what we're doing here.
#
# Bmad section 37.5: Multi-turn tracking.
#
# This describes how we can reuse the same cell, but it is in the programming section of Bmad, so it's actually referencing how to implement multi-turn tracking in Fortran, so again not what we're looking for.

# %% [markdown]
# With this in mind, we can create our accelerator and beam distribution

# %%
def make_lat():
        
    lat_text = f"""\
! Accelerator yay

parameter[particle] = proton
parameter[p0c] = 10.0e9
parameter[geometry] = open

particle_start[px] = 0.0
particle_start[py] = 0.0
beginning[beta_a]  = 10
beginning[alpha_a] = 0
beginning[beta_b]  = 10
beginning[alpha_b] = 0

d: drift, l = 1
cavity: lcavity, l = 0.2, voltage = 1e7, rf_frequency = 1e9, superimpose, offset = 0.5, phi0 = pi/6
cell: line = (d, cavity)
linac: line = (500*cell)

use, linac

"""

    with open('accelerator.bmad', 'w') as fi:
        fi.write(lat_text)

def make_init():
    init_text = f"""\
&tao_design_lattice
  n_universes = 1
  design_lattice(1)%file = "accelerator.bmad"
  design_lattice(1)%dynamic_aperture_calc = True
/

&tao_start
  startup_file = 'accelerator.tao'
/

! Modified from Tutorial:
! Simple Gaussian beam 
&tao_beam_init
beam_init%n_particle = 1000
beam_init%a_emit = 1.0e-7
beam_init%b_emit = 1.0e-7
beam_init%bunch_charge = 1e-9 ! 1 nC
beam_init%sig_z  = 2e-3
beam_init%sig_pz = 2e-3 ! normalized z-score std
saved_at = "*" ! Save distribution at all elements.
/

&tao_plot_page
  plot_page%size = 500, 500
  place(1) = 'r11', 'beam_plot'
/

! The correct tao.init form would be to separate plotting
! into a tao_plot.init file, which would contain all 
! the below namespaces.

! From Tao docs:

&tao_template_plot
plot%name = "beam_plot"
plot%n_graph = 1
/

&tao_template_graph
graph_index = 1
graph%name = "x"
graph%type = "phase_space"
graph%box = 1, 1, 1, 1
graph%title = "Z-Pz"
graph%margin = 0.15, 0.06, 0.12, 0.12, "%BOX"
graph%x%min = -15 ! heuristic
graph%x%max = 30
graph%y%min = -10
graph%y%max =  10 ! will be reset by scale anyways
graph%x%label = "z (mm)"
graph%x_axis_scale_factor = 1000.00 !m->mm
graph%y%label = "p\\dz\\u/p\\d0\\u (mrad)"
graph%y%major_div = 4
graph%y%label_offset=.4
curve(1)%data_type_x = "z"
curve(1)%data_type = "pz"
curve(1)%y_axis_scale_factor = 1000 !rad->mrad
curve(1)%data_source = "beam"
curve(1)%ele_ref_name = "END"
curve(1)%symbol_every = 10
curve(1)%symbol%type = 1
curve(1)%z_color%data_type = "energy"
curve(1)%z_color%is_on = T
/

! ---------- !

&tao_dynamic_aperture
  a_emit = 1e-7
  b_emit = 1e-7
  ellipse_scale = 3   ! Draw beam ellipse at n sigma
  pz = -0.01, 0, 0.01, 0.015
  da_param%n_angle = 30
  da_param%n_turn = 2 ! Low because we already have 500 cavities
  da_param%abs_accuracy = 1e-5
  da_param%min_angle = 0.01
  da_param%max_angle = 6.28
/

! dynamic aperture
&tao_template_plot
  plot%name = "da"
  default_graph%x%major_div_nominal = 10
  default_graph%x%label = "x (mm)"
  plot%x_axis_type = "phase_space"
  plot%n_graph = 1
  default_curve%y_axis_scale_factor = 1000
  default_curve%draw_symbols = T
  default_curve%data_type = "dynamic_aperture"
/

&tao_template_graph
  graph%name = "g1"
  graph%type = "dynamic_aperture"
  graph_index = 1
  # !graph%box = 1, 2, 1, 2
  graph%title = "Dynamic Aperture"
  graph%margin =  0.15, 0.06, 0.12, 0.12, "%BOX"
  graph%x_axis_scale_factor = 1000
  graph%y%label = "y (mm)"
  graph%y%label_offset = .2
  graph%y%max = 0 ! auto-set
  graph%y%min = 0
  graph%y%major_div = 4
  graph%n_curve = 10
  ! curve(1)%line%color = "red"
  ! curve(1)%data_type = "beam_ellipse"
  ! curve(1)%line%width = 5
  ! curve(1)%legend_text = "3 sigma beam ellipse"
  ! curve(1)%draw_symbols = F
  curve(2:10)%data_index = 1, 2, 3, 4, 5, 6, 7, 8, 9
  curve(3)%symbol%color = "purple"
  curve(3)%line%color = "purple"
 /



"""
    with open('tao.init', 'w') as fi:
        fi.write(init_text)

    with open('accelerator.tao', 'w') as fi:
        fi.write('set global track_type = beam')

# %%
from pytao import Tao
from pathlib import Path 
import matplotlib.pyplot as plt
import matplotlib.animation as animation

make_lat()
make_init()

init_file = Path.cwd() / "tao.init" # make sure Path.cwd() is this directory
tao = Tao(init_file=init_file, plot="mpl")

# %%
tao.plot('beam_plot')

# %% [markdown]
# This is all Tao plotting, just drawn using matplotlib instead of PGPLOT. I think we can still export PGPLOT to PostScript, but matplotlib has a lot more interesting features. Like: Animation!

# %%
tao.plot('beam_plot')
fig = plt.gcf()
axes = fig.get_axes()

def update(frame):
    tao.cmd(f'set curve T::beam_plot.x.c1 ix_ele_ref = {frame}')
    
    for ax in axes: # prevents drawing from being kept
        ax.clear()
    tao.plot('beam_plot', axes=axes, region_name='r11')
    
    fig.canvas.draw() 
    return axes

ani = animation.FuncAnimation(fig, update, frames=range(0,1000,5), interval=50, blit=False)
ani.save('beam_animation.gif', writer='pillow')

# %% [markdown]
# ---

# %% [markdown]
# For finding the area of the stable beam, we can use dynamic aperture, which I've included in the `tao.init` above, based on the `dynamic_aperture` tao example from the docs.

# %%
tao.plot('da')
# Out:
# No curve data for r12.g1.c1
# No curve data for r12.g1.c6
# No curve data for r12.g1.c7
# No curve data for r12.g1.c8
# No curve data for r12.g1.c9
# No curve data for r12.g1.c10
