# %% [markdown]
# # Phys 540 project 2
# # Andrew Koren

# %% [markdown]
# So, for both of these problems, or any problem with lots of matrix multiplication, a great package to pick up the work is Sympy, basically allowing for symbolic operations like Mathematica. For both of these problems, I'm going to use some Sympy code to implement each matrix.

# %%
from sympy import *

f, d = symbols('f d', real=True, positive=True)

Focusing = Matrix([[1,0],[-1/f,1]])
Drift = Matrix([[1,d],[0,1]])
Defocusing = Matrix([[1,0],[1/f,1]])

print('Focusing, Drift, Defocusing:')
display(Focusing, Drift, Defocusing)

print('beamline: FODO (matrix in reverse order)')
FODO = MatMul(Defocusing,Drift,Focusing,Drift, evaluate=False)
display(FODO)
display(simplify(FODO.doit()))
# Out:
# Focusing, Drift, Defocusing:
# Matrix([
# [   1, 0],
# [-1/f, 1]])
# Matrix([
# [1, d],
# [0, 1]])
# Matrix([
# [  1, 0],
# [1/f, 1]])
# beamline: FODO (matrix in reverse order)
# Matrix([
# [  1, 0],
# [1/f, 1]])*Matrix([
# [1, d],
# [0, 1]])*Matrix([
# [   1, 0],
# [-1/f, 1]])*Matrix([
# [1, d],
# [0, 1]])
# Matrix([
# [(-d + f)/f,       d*(-d + 2*f)/f],
# [   -d/f**2, -d**2/f**2 + d/f + 1]])

# %% [markdown]
# To show my work, I'll perform each matrix multiplication step-by-step using the code below:

# %%
def step_by_step_mul(operations: list):
    '''
    Matrix multiplication (xf) = [On,On-1,...,O2,O1](xi)
    '''
    O_r = operations[-1]
    for i in range(-1, -len(operations), -1):
            display(simplify(MatMul(*operations[0:i],O_r)))
            O_r = operations[i-1]*O_r
    result = expand(O_r)
    display(result)
    return result

result = step_by_step_mul([Defocusing,Drift,Focusing,Drift])
# Out:
# Matrix([
# [  1, 0],
# [1/f, 1]])*Matrix([
# [1, d],
# [0, 1]])*Matrix([
# [   1, 0],
# [-1/f, 1]])*Matrix([
# [1, d],
# [0, 1]])
# Matrix([
# [  1, 0],
# [1/f, 1]])*Matrix([
# [1, d],
# [0, 1]])*Matrix([
# [   1,          d],
# [-1/f, (-d + f)/f]])
# Matrix([
# [  1, 0],
# [1/f, 1]])*Matrix([
# [(-d + f)/f, d*(-d + 2*f)/f],
# [      -1/f,     (-d + f)/f]])
# Matrix([
# [-d/f + 1,        -d**2/f + 2*d],
# [ -d/f**2, -d**2/f**2 + d/f + 1]])

# %% [markdown]
# <!-- For question 2, I also have code to create a twiss propogation matrix from the transfer matrix
#
# ```python
#
# S, C, Sp, Cp = symbols('S C S\' C\' ')
# M = MatrixSymbol('M',3,3)
#
# Twiss_Propogation_Matrix = Matrix([
#     [C*C, -2*S*C, S*S],
#     [-C*Cp, Sp*C + S*C, -S*Sp],
#     [Cp*Cp, -2*Sp*Cp, Sp*Sp]
#     ])
# display(Eq(M, Twiss_Propogation_Matrix))
#
# def transfer_to_twiss(transfer_matrix):
#     '''Twiss 1D Parameter Evolution Matrix'''
#
#     [[a,b],[c,d]] = transfer_matrix.tolist()
#     parameters = {
#         C: a,
#         S: b,
#         Cp: c,
#         Sp: d
#         }
#     result = Twiss_Propogation_Matrix.subs(parameters)
#     return result
#
# ```
#
# where
# $$
#
#
#     K \equiv \begin{pmatrix}
#     \beta & - \alpha
# \\  -\alpha & \gamma
# \end{pmatrix}
# \\  K = M K_0 M^T
# $$ -->

# %% [markdown]
# For consistency, I'll use:
# - lower case for symbols
# - upper case for specific matricies
# - focusing/defocusing strength $f$ will be strictly positive.

# %% [markdown]
# ----

# %% [markdown]
# ## 1. Telescopic system.
# - the transfer matrix in the $x$-plane is

# %%
f_1, f_2 = symbols('f_1 f_2', real=True, positive=True)

F1 = Focusing.replace(f, f_1)
F2 = Focusing.replace(f, f_2)
O1 = Drift.replace(d,f_1)
O2 = Drift.replace(d,f_2)


Telescope = [O2,F2,O2,O1,F1,O1]
Transfer_x = step_by_step_mul(Telescope)
# Out:
# Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [     1, 0],
# [-1/f_2, 1]])*Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [1, f_1],
# [0,   1]])*Matrix([
# [     1, 0],
# [-1/f_1, 1]])*Matrix([
# [1, f_1],
# [0,   1]])
# Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [     1, 0],
# [-1/f_2, 1]])*Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [1, f_1],
# [0,   1]])*Matrix([
# [     1, f_1],
# [-1/f_1,   0]])
# Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [     1, 0],
# [-1/f_2, 1]])*Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [     0, f_1],
# [-1/f_1,   0]])
# Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [     1, 0],
# [-1/f_2, 1]])*Matrix([
# [-f_2/f_1, f_1],
# [  -1/f_1,   0]])
# Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [-f_2/f_1,      f_1],
# [       0, -f_1/f_2]])
# Matrix([
# [-f_2/f_1,        0],
# [       0, -f_1/f_2]])

# %% [markdown]
# This yields both $\langle x | x' \rangle = 0$ and $\langle x'|x \rangle=0$, so the system is both imaging and telescoping in the x-plane. However, for the y-plane, we have

# %%
# the 'focusing' magnets have a defocusing effect on y
# I still call them F1, F2 for consistency
F1_y = F1.subs(f_1,-f_1)
F2_y = F2.subs(f_2,-f_2)

Telescope = [O2,F2_y,O2,O1,F1_y,O1] 
Transfer_y = step_by_step_mul(Telescope)
# Out:
# Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [    1, 0],
# [1/f_2, 1]])*Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [1, f_1],
# [0,   1]])*Matrix([
# [    1, 0],
# [1/f_1, 1]])*Matrix([
# [1, f_1],
# [0,   1]])
# Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [    1, 0],
# [1/f_2, 1]])*Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [1, f_1],
# [0,   1]])*Matrix([
# [    1, f_1],
# [1/f_1,   2]])
# Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [    1, 0],
# [1/f_2, 1]])*Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [    2, 3*f_1],
# [1/f_1,     2]])
# Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [    1, 0],
# [1/f_2, 1]])*Matrix([
# [2 + f_2/f_1, 3*f_1 + 2*f_2],
# [      1/f_1,             2]])
# Matrix([
# [1, f_2],
# [0,   1]])*Matrix([
# [  2 + f_2/f_1, 3*f_1 + 2*f_2],
# [2/f_2 + 2/f_1, 3*f_1/f_2 + 4]])
# Matrix([
# [4 + 3*f_2/f_1, 6*f_1 + 6*f_2],
# [2/f_2 + 2/f_1, 3*f_1/f_2 + 4]])

# %% [markdown]
# which explains why the system does not work in the y-plane

# %% [markdown]
# - Now we'll use $K=M K_0 M^T$ to find $\alpha$ and $\beta$ at position $x_1$ and $x_2$
#
# $$
#     K \equiv \begin{pmatrix}
#     \beta & - \alpha
# \\  -\alpha & \gamma
# \end{pmatrix}
# $$

# %% [markdown]
# <!-- alpha_1, alpha_2, beta_1, beta_2, gamma_1, gamma_2 = symbols('alpha_(1:3) beta_(1:3) gamma_(1:3)')
#
# K_1 = Matrix([
#     [beta_1, -alpha_1],
#     [-alpha_1, gamma_1]
#     ])
# K_2 = Matrix([
#     [beta_2, -alpha_2],
#     [-alpha_2, gamma_2]
#     ])
#
# K_1f = simplify(expand(Transfer_x * K_1 * Transfer_x.T))
# K_2f = simplify(expand(Transfer_y * K_2 * Transfer_y.T))
#
# display(K_1f, K_2f) -->

# %%
alpha_1, alpha_2, beta_1, beta_2, gamma_1, gamma_2 = symbols('alpha_(1:3) beta_(1:3) gamma_(1:3)', real=True)

K1 = Matrix([
    [beta_1, -alpha_1],
    [-alpha_1, gamma_1]
    ])
K2 = Matrix([
    [beta_2, -alpha_2],
    [-alpha_2, gamma_2]
    ])

Eq(K2, Transfer_x*K1*Transfer_x.T)
# Out:
# Eq(Matrix([
# [  beta_2, -alpha_2],
# [-alpha_2,  gamma_2]]), Matrix([
# [beta_1*f_2**2/f_1**2,              -alpha_1],
# [            -alpha_1, f_1**2*gamma_1/f_2**2]]))

# %% [markdown]
# Element-by-element, we see $\alpha$ is unchanged, while $\beta$ is scaled by ${f_2^2 \over f_1^2}$

# %% [markdown]
# - For phase advance, we'll use
# $$
# \begin{array}{c}
#        \cos \Delta \psi
#     = {\langle x|x\rangle \beta_1 - \langle x|x'\rangle\alpha_1 \over \sqrt{\beta_1 \beta_2}}
# \\    \sin \Delta \psi
#     = {\langle x|x'\rangle \over \sqrt{\beta_1 \beta_2}}
# \end{array}
# $$

# %%
[a, b], [_, _] = Transfer_x.tolist()
beta_2 = beta_1 * f_2*f_2 / (f_1*f_1)

cos_dpsi = expand((a*beta_1 - b * alpha_1)/(sqrt(beta_1*beta_2)))
sin_dpsi = expand(b/sqrt(beta_1*beta_2))
display(cos_dpsi, sin_dpsi)
# Out:
# -beta_1/Abs(beta_1)
# 0

# %% [markdown]
# The cosine term reduces down to $\cos^{-1}(-1)=\pi$ in agreement with the sine term. Note that $-\pi$ phase advance is the same as $\pi$ phase advance.

# %% [markdown]
# - For telescoping in both planes, we'll need defocusing as well as focusing, with less obvious distances. I'm quite lazy, so I've copied the diagram from class below
#
# ![image.png](attachment:image.png)

# %% [markdown]
# I genuinely struggled with trying to brute-force this system until getting some help during office hours.
# The hint was to assume the solution is a superposition between a telescope in the $x$-plane and one in the $y$-plane,
# including the $f$ and $l$ relationships, all with thin-lens approximation.
#
# $$
# \begin{array}{c:c:c}
#     l_1 + l_2 = f_2
#  &  l_3 + l_4 = f_2 + f_4
#  &  l_5 = f_4
# \\  l_1 = f_1
#  &  l_2 + l_3 = f_1 + f_3
#  &  l_4 + l_5 = f_3
# \end{array}
# $$
#
# These are great linear equations, and sympy can find how many terms must be independent immediately.
# <!-- We can work down some relations between $l$'s from these.
#
# $$
# \begin{array}
# \\  l_1 + l_2 = f_2
#  &  l_3 + l_4 = f_2 + l_5
# \\  l_2 + l_3 = l_1 + f_3
#  &  l_4 + l_5 = f_3
# \end{array}
# $$
# $$
# \begin{array}
# \\  l_3 = l_1 + l_2 + l_5 - l_4
# \\  l_3 = l_1 + l_4 + l_5 - l_2
# \end{array}
# $$
# Now for the transfer matricies -->

# %% [markdown]
# ---

# %%
drift_lengths = symbols('l_(1:6)', real=True, positive=True)
l_1, l_2, l_3, l_4, l_5 = drift_lengths
f_3, f_4 = symbols('f_3 f_4', real=True, positive=True)

eqns = [
    l_1 + l_2 - f_2,
    l_3 + l_4 - f_2 - f_4,
    l_5 - f_4,
    l_1 - f_1,
    l_2 + l_3 - f_1 - f_3,
    l_4 + l_5 - f_3
]

relations = solve(eqns)
display(relations)
# Out:
# {f_1: l_3 - l_5,
#  f_2: l_3 + l_4 - l_5,
#  f_3: l_4 + l_5,
#  f_4: l_5,
#  l_1: l_3 - l_5,
#  l_2: l_4}

# %% [markdown]
# From this point onward, I struggled to get any solutions which boild down nicely, and I gave up once Project 3 was released.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Quarter-Wave
#
# We can do this pretty easily with sympy again. We already know a lot about our transfer matrix from the general equation
#
# $$
# M = \begin{pmatrix}
#     \sqrt{\beta_2 \over \beta_1} \left(\cos \mu + \alpha_1 \sin \mu \right)
# &   \sqrt{\beta_1 \beta_2} \sin \mu
# \\  -{1 + \alpha_1\alpha_2 \over \sqrt{\beta_1 \beta_2}} \sin \mu
#     - {\alpha_2 - \alpha_1 \over \sqrt{\beta_1 \beta_2}} \cos \mu
# &   \sqrt{\beta_2 \over \beta_1} \left( \cos \mu - \alpha_2 \sin \mu \right)
# \end{pmatrix}
# $$
#
# For $\mu = {\pi \over 2}$ this gives
#
# $$
# M = \begin{pmatrix}
#     \sqrt{\beta_2 \over \beta_1} \alpha_1
# &   \sqrt{\beta_1 \beta_2}
# \\  -{1 + \alpha_1\alpha_2 \over \sqrt{\beta_1 \beta_2}}
# &   -\alpha_2 \sqrt{\beta_2 \over \beta_1}
# \end{pmatrix}
# $$
#
# Following our discussion in class, we're going to use $f = {l \over \sqrt{2}}$ to support our quarter-wave requirement

# %%
l, q1, q2 = symbols('l Q1 Q2', real=True, positive=True)
beta_1, beta_2 = symbols('beta_1, beta_2', real=True, positive=True)
gamma_1, gamma_2, alpha_1, alpha_2 = symbols('gamma_1 gamma_2 alpha_1 alpha_2', real=True)

Quarter_Wave = Matrix([
    [sqrt(beta_2/beta_1)*alpha_1, sqrt(beta_1*beta_2)],
    [-(1+alpha_1*alpha_2)/sqrt(beta_1*beta_2), - alpha_2 * sqrt(beta_1/beta_2)]
])

L12 = Drift.replace(d, l/2)
L = Drift.replace(d,l)
F = Focusing.subs(f, l/sqrt(2))
D = Defocusing.subs(f, l/sqrt(2))
Q1 = Defocusing.subs(f, q1)
Q2 = Focusing.subs(f, q2)

# should we keep f = l/sqrt(2)? Yep, garuntees µ=π/2
Elements = [Q2,L12,D,L,F,L12,Q1] 

Beam_Line = step_by_step_mul(Elements)

#display(Quarter_Wave)
display(Eq(Quarter_Wave, Beam_Line))
# Out:
# Matrix([
# [    1, 0],
# [-1/Q2, 1]])*Matrix([
# [1, l/2],
# [0,   1]])*Matrix([
# [        1, 0],
# [sqrt(2)/l, 1]])*Matrix([
# [1, l],
# [0, 1]])*Matrix([
# [         1, 0],
# [-sqrt(2)/l, 1]])*Matrix([
# [1, l/2],
# [0,   1]])*Matrix([
# [   1, 0],
# [1/Q1, 1]])
# Matrix([
# [    1, 0],
# [-1/Q2, 1]])*Matrix([
# [1, l/2],
# [0,   1]])*Matrix([
# [        1, 0],
# [sqrt(2)/l, 1]])*Matrix([
# [1, l],
# [0, 1]])*Matrix([
# [         1, 0],
# [-sqrt(2)/l, 1]])*Matrix([
# [(Q1 + l/2)/Q1, l/2],
# [         1/Q1,   1]])
# Matrix([
# [    1, 0],
# [-1/Q2, 1]])*Matrix([
# [1, l/2],
# [0,   1]])*Matrix([
# [        1, 0],
# [sqrt(2)/l, 1]])*Matrix([
# [1, l],
# [0, 1]])*Matrix([
# [                      (Q1 + l/2)/Q1,           l/2],
# [(2*l - sqrt(2)*(2*Q1 + l))/(2*Q1*l), 1 - sqrt(2)/2]])
# Matrix([
# [    1, 0],
# [-1/Q2, 1]])*Matrix([
# [1, l/2],
# [0,   1]])*Matrix([
# [        1, 0],
# [sqrt(2)/l, 1]])*Matrix([
# [(2*Q1 + 3*l - sqrt(2)*(2*Q1 + l))/(2*Q1), l*(3 - sqrt(2))/2],
# [     (2*l - sqrt(2)*(2*Q1 + l))/(2*Q1*l),     1 - sqrt(2)/2]])
# Matrix([
# [    1, 0],
# [-1/Q2, 1]])*Matrix([
# [1, l/2],
# [0,   1]])*Matrix([
# [(2*Q1 + 3*l - sqrt(2)*(2*Q1 + l))/(2*Q1), l*(3 - sqrt(2))/2],
# [                       -2/l + sqrt(2)/Q1,           sqrt(2)]])
# Matrix([
# [    1, 0],
# [-1/Q2, 1]])*Matrix([
# [-sqrt(2) + 3*l/(2*Q1),   3*l/2],
# [    -2/l + sqrt(2)/Q1, sqrt(2)]])
# Matrix([
# [                         -sqrt(2) + 3*l/(2*Q1),                3*l/2],
# [-2/l + sqrt(2)/Q2 + sqrt(2)/Q1 - 3*l/(2*Q1*Q2), sqrt(2) - 3*l/(2*Q2)]])
# Eq(Matrix([
# [                 alpha_1*sqrt(beta_2)/sqrt(beta_1),          sqrt(beta_1)*sqrt(beta_2)],
# [(-alpha_1*alpha_2 - 1)/(sqrt(beta_1)*sqrt(beta_2)), -alpha_2*sqrt(beta_1)/sqrt(beta_2)]]), Matrix([
# [                         -sqrt(2) + 3*l/(2*Q1),                3*l/2],
# [-2/l + sqrt(2)/Q2 + sqrt(2)/Q1 - 3*l/(2*Q1*Q2), sqrt(2) - 3*l/(2*Q2)]]))

# %% [markdown]
# This matrix isn't super simple, but the top-right term is useful
#
# $$
# \begin{array}{c}
#   {3 l \over 2} = \sqrt{\beta_1 \beta_2}
# \\l = {2 \over 3} \sqrt{\beta_1 \beta_2}
# \end{array}
# $$
#
# Let's start working through things with sympy

# %%
QW_Beam_Line = Beam_Line.subs(l, Rational(2,3)*sqrt(beta_1*beta_2))
q1_sol = solve(Eq(Quarter_Wave[0,0], QW_Beam_Line[0,0]), q1)[0]
display(Eq(q1, q1_sol))

q2_sol = solve(Eq(Quarter_Wave[1,1], QW_Beam_Line[1,1]), q2)[0]
display(Eq(q2, q2_sol))
# Out:
# Eq(Q1, beta_1*sqrt(beta_2)/(alpha_1*sqrt(beta_2) + sqrt(2)*sqrt(beta_1)))
# Eq(Q2, sqrt(beta_1)*beta_2/(alpha_2*sqrt(beta_1) + sqrt(2)*sqrt(beta_2)))

# %% [markdown]
# Easy peasy! By construction this should turn our beamline to turn into the general quarter-wave matrix

# %%
QW_complete = QW_Beam_Line.subs({q1: q1_sol, q2: q2_sol}).expand()
display(QW_complete)

K1 = Matrix([
    [beta_1, -alpha_1],
    [-alpha_1, (1+alpha_1*alpha_1)/beta_1]
])

display(simplify(QW_complete*K1*QW_complete.T))
# Out:
# Matrix([
# [                                           alpha_1*sqrt(beta_2)/sqrt(beta_1),          sqrt(beta_1)*sqrt(beta_2)],
# [-alpha_1*alpha_2/(sqrt(beta_1)*sqrt(beta_2)) - 1/(sqrt(beta_1)*sqrt(beta_2)), -alpha_2*sqrt(beta_1)/sqrt(beta_2)]])
# Matrix([
# [  beta_2,                -alpha_2],
# [-alpha_2, (alpha_2**2 + 1)/beta_2]])

# %% [markdown]
# That confirms our transfer matricies work independent of $\alpha$ and $\beta$ choice. We can encode our $l$ and $Q_1/Q_2$ based on our target twiss parameters. We also have
#
# $$
# f = { \sqrt{2} \over 3} {\sqrt{\beta_1 \beta_2}}
# $$

# %% [markdown]
# ---

# %% [markdown]
# For plotting, we could go one-by-one and find the twiss parameters after each element, but I think this is a great time to try out PyTao. Pytao is just a wrapper of Tao, but it's great for making really simple plots like alpha/beta plots inside of a jupyter notebook. I'm running this notebook within my WSL since it requires a Tao installation.

# %%
params = {
    beta_1: 5,
    beta_2: 50,
    alpha_1: 1,
    alpha_2: 1,
}

def fill_in_params(params):
    params[l] = Rational(2,3)*sqrt(params[beta_1]*params[beta_2])
    params[f] = params[l]/sqrt(2)
    params[q1] = q1_sol.subs(params)
    params[q2] = q2_sol.subs(params)

fill_in_params(params)

K1_symb, K2_symb, M_symb = [MatrixSymbol(k, 2, 2) for k in ('K1', 'K2', 'M')]

display(Eq(M_symb, Beam_Line.subs(params).evalf()))
display(Eq(K1_symb,K1.subs(params).evalf()))
display(Eq(K2_symb, (Beam_Line.subs(params)*K1.subs(params)*Beam_Line.subs(params).T).evalf()))
params
# Out:
# Eq(M, Matrix([
# [  3.16227766016838,   15.8113883008419],
# [-0.126491106406735, -0.316227766016838]]))
# Eq(K1, Matrix([
# [ 5.0, -1.0],
# [-1.0,  0.4]]))
# Eq(K2, Matrix([
# [50.0, -1.0],
# [-1.0, 0.04]]))
# {beta_1: 5,
#  beta_2: 50,
#  alpha_1: 1,
#  alpha_2: 1,
#  l: 10*sqrt(10)/3,
#  f: 10*sqrt(5)/3,
#  Q1: 25*sqrt(2)/(sqrt(10) + 5*sqrt(2)),
#  Q2: 50*sqrt(5)/(sqrt(5) + 10)}

# %%
# conda install -c conda-forge pytao

# %% [markdown]
# Lets create a init file and lattice before starting up Tao.

# %%
def make_lattice(params):
    k_Q1 = float(params[q1].evalf())
    k_Q2 = float(params[q2].evalf())
    k_f  = float(params[f].evalf())
    
    lat_text = f"""\
! lattice setup
beginning[alpha_a] = { params[alpha_1]}.   ! m  a-mode alpha function
beginning[alpha_b] = {-params[alpha_1]}.   ! m  b-mode = -a-mode

beginning[beta_a] = {params[beta_1]}.     ! m  a-mode beta  function
beginning[beta_b] = {params[beta_1]}.     ! m  b-mode = a-mode

beginning[e_tot] = 10e6   ! eV shouldn't matter for magnets

parameter[geometry] = open

L:  drift, L = {float(params[l].evalf())}
L2: drift, L = {float(params[l].evalf())/2}
Q1: multipole, L = 0.0, k1l = {-1/k_Q1}
Q2: multipole, L = 0.0, k1l = { 1/k_Q2}
F:  multipole, L = 0.0, k1l = { 1/k_f}
D:  multipole, L = 0.0, k1l = {-1/k_f}

lat: line = (Q1, L2, F, L, D, L2, Q2)     ! Start to finish
use, lat                    

"""

    with open('QuarterWave.bmad', 'w') as fi:
        fi.write(lat_text)

def make_init():
    init_text = f"""\
&tao_design_lattice
  n_universes = 1
  design_lattice(1)%file = "QuarterWave.bmad"
/

&tao_plot_page
  plot_page%size = 500, 500
  place(1) = 'r12', 'alpha'
  place(2) = 'r22', 'beta'
/
"""
    with open('tao.init', 'w') as fi:
        fi.write(init_text)

# %% [markdown]
# Now we can make our plots using the paramaters we found through sympy

# %%
from pytao import Tao
import matplotlib.pyplot as plt
from pathlib import Path 
import os

original_dir = os.getcwd()
print(original_dir)
# Out:
# /home/andre/bmad_files/project_2

# %%
if os.getcwd().split('/')[-1] != 'project_2':
    os.chdir(original_dir)

make_lattice(params)
make_init()

init_file = Path.cwd() / "tao.init" # make sure Path.cwd() is this directory
tao = Tao(init_file=init_file, plot="mpl")
tao.show('lat')
# Out:
# ['# Values shown are for the Downstream End of each Element (Girder elements shown at ref point):',
#  '# Index  name      key                       s       l    beta   phi_a    eta   orbit    beta   phi_b    eta   orbit  Track',
#  '#                                                            a   [2pi]      x  x [mm]       b   [2pi]      y  y [mm]  State',
#  '      0  BEGINNING Beginning_Ele         0.000     ---    5.00   0.000   0.00   0.000    5.00   0.000   0.00   0.000  Alive',
#  '      1  Q1        Multipole             0.000   0.000    5.00   0.000   0.00   0.000    5.00   0.000   0.00   0.000  Alive',
#  '      2  L2        Drift                 5.270   5.270   16.38   0.099   0.00   0.000    6.95   0.176   0.00   0.000  Alive',
#  '      3  F         Multipole             5.270   0.000   16.38   0.099   0.00   0.000    6.95   0.176   0.00   0.000  Alive',
#  '      4  L         Drift                15.811  10.541   14.53   0.219   0.00   0.000  108.81   0.239   0.00   0.000  Alive',
#  '      5  D         Multipole            15.811   0.000   14.53   0.219   0.00   0.000  108.81   0.239   0.00   0.000  Alive',
#  '      6  L2        Drift                21.082   5.270   50.00   0.250   0.00   0.000   50.00   0.250   0.00   0.000  Alive',
#  '      7  Q2        Multipole            21.082   0.000   50.00   0.250   0.00   0.000   50.00   0.250   0.00   0.000  Alive',
#  '      8  END       Marker               21.082   0.000   50.00   0.250   0.00   0.000   50.00   0.250   0.00   0.000  Alive',
#  '# Index  name      key                       s       l    beta   phi_a    eta   orbit    beta   phi_b    eta   orbit  Track',
#  '#                                                            a   [2pi]      x  x [mm]       b   [2pi]      y  y [mm]  State',
#  '# Values shown are for the Downstream End of each Element (Girder elements shown at ref point):']

# %%
tao.plot(["alpha", "beta"])

# %% [markdown]
# We did it! Using `multipole` was key since it is bmad's built in thin lens, hence the lack of any elements on the layout

# %% [markdown]
# In addition, we can see the transfer matrix is the same as our design

# %%
tao.cmds(["show mat"])
# Out:
# [['From: BEGINNING',
#   'To:   END',
#   'Symplectic Error:  6.66E-16',
#   '',
#   '     3.16227766    15.81138830     0.00000000     0.00000000     0.00000000     0.00000000   :  0.00000000E+00',
#   '    -0.12649111    -0.31622777     0.00000000     0.00000000     0.00000000     0.00000000   :  0.00000000E+00',
#   '     0.00000000     0.00000000    -3.16227766    15.81138830     0.00000000     0.00000000   :  0.00000000E+00',
#   '     0.00000000     0.00000000    -0.12649111     0.31622777     0.00000000     0.00000000   :  0.00000000E+00',
#   '     0.00000000     0.00000000     0.00000000     0.00000000     1.00000000     0.05504891   :  0.00000000E+00',
#   '     0.00000000     0.00000000     0.00000000     0.00000000     0.00000000     1.00000000   :  0.00000000E+00']]

# %% [markdown]
# ## 3. Dispersion Supression
#
# As per usual, we'll start with the linear algebra. A dipole has the transfer matrix
#
# $$
# M = \begin{pmatrix}
# \cos\left(l \over \rho \right) &
# \rho \sin \left(l \over \rho \right) \\
# - {1 \over \rho} \sin \left( l \over \rho \right) &
# \cos\left(l \over \rho \right)
# \end{pmatrix}
# $$
#
# Which, in addition contribute the particular component
#
#
# $$
# \begin{gathered}
# D(s) = \rho \left( 1 - \cos \left( l \over \rho \right) \right) \\
# D'(s) = \sin \left( l \over \rho \right)
# \end{gathered}
# $$
#
# In lecture 6 we derived that a closed system must have $\eta(s+C) = \eta$, and found a simple equation for dispersion
#
# $$
# \begin{gathered}
# \eta = \frac{(1-S')D+SD'}{2(1-\cos(\mu))} \\
# \eta' = \frac{(1-C)D'+C'D}{2(1-\cos(\mu))}
# \end{gathered}
# $$
#
# What does the $\pi \over 2$ dispersion suppression segment from lecture 8 have for this?
# <!-- $$
# \begin{gathered}
# \begin{pmatrix}
# \eta \\ \eta' \\ 1
# \end{pmatrix}
# =
# \begin{pmatrix}
# C & S & D \\
# C' & S' & D' \\
# 0 & 0 & 1
# \end{pmatrix}
# \begin{pmatrix}
# \eta \\ \eta' \\ 1
# \end{pmatrix}
# \end{gathered}
# $$ -->

# %% [markdown]
# I was very confused with this portion until we went back over the notes. To design dispersion supression we use two bending FODO cells such that the total angle $\theta_C$ is split between the two
#
# $$
# \begin{gathered}
#     \mathcal{M}^{\theta_C} = M_{\text{FODO}}^{\theta_1} \cdot M_{\text{FODO}}^{\theta_2}
# \\  \theta_C = \theta_1 + \theta_2
# \end{gathered}
# $$
# In the slides, we derive
# $$
# \begin{gathered}
#     \theta_1 = \left( 1 - {1 \over 2(1-\cos \mu)} \right) \theta
# \\  \theta_2 = {1 \over 2(1-\cos \mu)} \theta
# \end{gathered}
# $$
# For $\pi \over 3$ this yields
# $$
# \theta_1 = 0 \quad \theta_2 = \theta
# $$
#
# I've attempted to generalize our code below, although I've left in a lot of hard-coded values that I didn't really want to touch. This should work for a variety of $\mu$, but I haven't tested it out much.

# %%
from numpy import pi as PI

def make_ds_lattice(params):
    # hard-coded vales
    circumference = 200.0 
    ldip = 8.0
    
    # One FODO cell (thin quad): F O Sb O D D O Sb O F
    # -> lcell is the length 2F + 4O + 2Sb + 2D
    # -> we use zero-length quads
    
    n = params['n']
    m = params['m']
    
    cell_angle =  PI / (n + 2) # leaves room for 2 more cells
    th_1 = (1 - m) * cell_angle
    th_2 = m * cell_angle
    
    lcell = circumference / n / 2

    ldrift = (lcell - 2*ldip)/4 
    assert ldrift > 0

    lquad = 1.0 # are we using thin lens?
        
    lat_text = f"""\
! Dispersion section design pi/3

parameter[particle] = proton
parameter[p0c] = 10.0 * 1e9
parameter[geometry] = closed

! pre-set quad strengths?

qf: quad, l={lquad}/2, k1= 0.1
qd: quad, l={lquad}/2, k1=-0.1

qf_ring: qf       ! ring does not use dispersion supression
qf_racetrack: qf  ! racetrack needs ds to go from straight -> bending -> straight
qf_straight: qf
qf_ds: qf

qd_ring: qd
qd_racetrack: qd
qd_straight: qd
qd_ds: qd

d: drift, l={ldrift}
dd: d,    l={ldip}

ring_dipole: sbend, l={ldip}, angle=pi/{n}/2
race_dipole: ring_dipole, angle={cell_angle/2}
sup_dipole1: ring_dipole, angle={th_1}
sup_dipole2: ring_dipole, angle={th_2}

m: marker

! set up each cell/segment
cell_ring:      line = (qf_ring,      d, ring_dipole, d, 2*qd_ring,      d, ring_dipole, d, qf_ring)
cell_racetrack: line = (qf_racetrack, d, race_dipole, d, 2*qd_racetrack, d, race_dipole, d, qf_racetrack)
cell_straight:  line = (qf_straight, d, dd, d, 2*qd_straight, d, dd, d, qf_straight)
cell_drift_supression: line = 
                       (qf_ds,        d, sup_dipole1, d, 2*qd_ds,        d, sup_dipole2, d, qf_ds)

! combine into half-rings
half_ring: line = ({n}*cell_ring)
half_racetrack: line = (--cell_drift_supression, {n}*cell_racetrack, cell_drift_supression)

! combine into full rings
ring: line = (2*half_ring)
racetrack: line = (5*cell_straight, m, half_racetrack, m, 5*cell_straight, m, half_racetrack)

! individual cells branched for optimization

# !use, ring
use, racetrack

"""

    with open('pi3_ds.bmad', 'w') as fi:
        fi.write(lat_text)

def make_ds_init(params):
    
    mu = float(params['mu'].evalf())

    init_text = f"""\
&tao_design_lattice
  n_universes = 1
  design_lattice(1)%file = "pi3_ds.bmad"
/

! Sets custom plot page settings
&tao_plot_page
	plot_page%size = 400, 400
	plot_page%text_height = 8
	plot_page%n_curve_pts = 5000
/

! For all optimizations, we must define at least one tao_d2_data, 
! to contain the tao_d1_data. Exact structuring of d2 and d1 data 
! is up to you; Tao does not care.
&tao_d2_data
  	d2_data%name = 'phase'
  	n_d1_data = 1
/

! tao_d1_data contains the actual matching conditions
! Here, we want to match to pi/2 phase advance in x and y at the end
&tao_d1_data
	ix_d1_data = 1
	datum(1) = 'phase.a' '' '' 'end' 'target' {mu} 10
	datum(2) = 'phase.b' '' '' 'end' 'target' {mu} 10
/

! These are the variables; the things to vary to satisfy the "data"
! We vary the quadrupoles' k1 values
&tao_var
	v1_var%name = 'quads'
	var(1:2)%ele_name = "QF*", "QD*"
	default_step = 1e-6
	default_attribute = 'k1'
/

"""
    with open('tao_ds.init', 'w') as fi:
        fi.write(init_text)

# %%
if os.getcwd() == original_dir:
    os.chdir(Path.cwd() / "dispersion_suppression_tune")

mu = pi*Rational(1,3)
m = 1/(2*(1-cos(mu)))
params = {
    'n': 5,
    'm': float(m.evalf()),
    'mu': mu
}

make_ds_lattice(params)
make_ds_init(params)

init_file = "tao_ds.init" 
lattice_file = "pi3_ds.bmad"
tao = Tao(init_file=init_file, lattice_file=lattice_file, plot="mpl")
tao.plot('floor', xlim = (-100, 200), ylim = (-150, 75))

# %% [markdown]
# Looks well formed, lets see our dispersion.

# %%
tao.plot('eta')

# %% [markdown]
# This isn't doing what we want, but we haven't optimized our magnets to be FODO cells to be $\pi/3$ yet. We can do this numerically or analytically via linear algebra relations, but I should probably be learning bmad optimization. We can optimize individual cells one-at-a-time by setting a reference element before the start of the cell (since element phases are measured from their endpoint)

# %%
display(tao.cmd('show data phase'))
display(tao.cmd('show ele QF_ST*')[0:4])
display(tao.cmd('show ele QF_DS*')[0:4])
display(tao.cmd('show ele QF_RA*')[0:4])
# Out:
# ['Data name: phase.1',
#  '                                                                                                        |   Useit',
#  '                         Ref_Ele   Start_Ele   Ele                 Meas           Model          Design | Opt  Plot',
#  '    1  phase.a <target>                        END        1.0471976E+00   2.9482022E+01   2.9482022E+01     T     F',
#  '    2  phase.b <target>                        END        1.0471976E+00   2.6985397E+01   2.6985397E+01     T     F',
#  '                         Ref_Ele   Start_Ele   Ele                 Meas           Model          Design | Opt  Plot',
#  '                                                                                                        |   Useit']
# ['         1  QF_STRAIGHT                                      0.500',
#  '        10  QF_STRAIGHT                                     22.000',
#  '        11  QF_STRAIGHT                                     22.500',
#  '        20  QF_STRAIGHT                                     44.000']
# ['        52  QF_DS                                          110.500',
#  '        61  QF_DS                                          132.000',
#  '       112  QF_DS                                          242.500',
#  '       121  QF_DS                                          264.000']
# ['        62  QF_RACETRACK                                   132.500',
#  '        71  QF_RACETRACK                                   154.000',
#  '        72  QF_RACETRACK                                   154.500',
#  '        81  QF_RACETRACK                                   176.000']

# %% [markdown]
# One cell has a QF at the start and end, so these values tell us our cell starts/ends. We can extract these indicies into lists pretty easily with `pipe`

# %%
# string info:
# universe@branch>>element|{which} {what}
# which is design, model, base, 
# what is found in tao manual

Straight_cell_ix = tao.cmd('pipe lat_list 1@0>>QF_S*|base  ele.ix_ele')[0:2]
DS_cell_ix       = tao.cmd('pipe lat_list 1@0>>QF_DS*|base ele.ix_ele')[0:2]
Race_cell_ix     = tao.cmd('pipe lat_list 1@0>>QF_RA*|base ele.ix_ele')[0:2]

# %%
# string info:
# universe@d2.d1[i]|{what}
# [i] is datum i, leaving blank will select all i
# I'm using data:: just for safety 
# what is found in tao manual

def set_data_ix(ixs):
    start, end = ixs

    start_str = f'set data 1@data::phase.1|ix_ele_ref = {int(start)-1}'
    end_str   = f'set data 1@data::phase.1|ix_ele = {int(end)}'

    tao.cmd(start_str)
    tao.cmd(end_str)

set_data_ix(Straight_cell_ix)
tao.show('data phase.1') 

# Start_Ele is for optimizing a value in a range
# Ref_Ele is for optimizing relative to a value (target - ref), works for phase
# Out:
# ['Data name: phase.1',
#  '                                                                                                            |   Useit',
#  '                         Ref_Ele    Start_Ele   Ele                    Meas           Model          Design | Opt  Plot',
#  '    1  phase.a <target>  BEGINNING              QF_STRAIGHT   1.0471976E+00   1.1691740E+00   1.1691740E+00     T     F',
#  '    2  phase.b <target>  BEGINNING              QF_STRAIGHT   1.0471976E+00   1.1243915E+00   1.1243915E+00     T     F',
#  '                         Ref_Ele    Start_Ele   Ele                    Meas           Model          Design | Opt  Plot',
#  '                                                                                                            |   Useit']

# %% [markdown]
# We also only want to adjust the quad strength of our target cell, so we'll modify our variables. Alongside output `pipe` subcommands, there are also action `pipe` subcommands which can create/destroy variables. We can turn off our ring-wide quad variable using `veto` so we don't need to get rid of it.

# %%
tao.cmd('veto var quads')
display(tao.cmd('show variable quads')) # Useit_opt = F
# Out:
# ['  Variable                   Slave Parameters           Meas         Model        Design  Useit_opt',
#  '  quads[1]                   QF*[K1]                0.0000E+00    1.0000E-01    1.0000E-01       F',
#  '  quads[2]                   QD*[K1]                0.0000E+00   -1.0000E-01   -1.0000E-01       F',
#  '  Variable                   Slave Parameters           Meas         Model        Design  Useit_opt']

# %%
def create_var(ixs, ele_name, var, attribute='k1'):
    # hardcoded vals
    universes = '1'
    weight = '0'
    step = '1e-6'
    low = '-1e30'
    high = '1e30'
    merit_type = 'limit'
    good_user = 'T'
    key_bound = 'F'
    key_delta = '0'

    start, end = ixs

    # tao ranges are inclusive [a,b]
    lat_ele_names = tao.cmd(f'pipe lat_list 1@0>>{start}:{end}|base  ele.name')

    ele_ix = []
    ele_str = ''
    for i, lat_ele in enumerate(lat_ele_names, start=int(start)):
        if lat_ele == ele_name:
            ele_ix.append(i)
            ele_str += f'{i},'

    if len(ele_ix) == 0:
        return 0

    ele_str = ele_str[:-1] # trim last comma

    try:
        tao.cmd(f"pipe var_create {var}^^{ele_str}^^{attribute}^^{universes}"
                f"^^{weight}^^{step}^^{low}^^{high}^^{merit_type}"
                f"^^{good_user}^^{key_bound}^^{key_delta}")
        return 1
    except:
        return 2

# %%
tao.cmd('pipe var_v1_create cell_quads 1 2')

set_data_ix(Straight_cell_ix)
status1 = create_var(Straight_cell_ix, 'QF_STRAIGHT', var = 'cell_quads[1]') #nvm we're overwritting them
status2 = create_var(Straight_cell_ix, 'QD_STRAIGHT', var = 'cell_quads[2]')

assert status1
assert status2

tao.cmd('show var')
# Out:
# ['       Name                                      Using for Optimization',
#  '    quads[1:2]',
#  '    cell_quads[1:2]']

# %% [markdown]
# Alright, let's see if the optimization will work for this cell.

# %%
# %%tao
#
# show data phase
# show var cell_quads
# alias opt run lm
# set branch 0 geometry = open ! avoid re-computing trajectories
# opt
# show data phase
# Out:
# --------------------
# Tao> show data phase
# Data name: phase.1
#                                                                                                             |   Useit
#                          Ref_Ele    Start_Ele   Ele                    Meas           Model          Design | Opt  Plot
#     1  phase.a <target>  BEGINNING              QF_STRAIGHT   1.0471976E+00   1.1691740E+00   1.1691740E+00     T     F
#     2  phase.b <target>  BEGINNING              QF_STRAIGHT   1.0471976E+00   1.1243915E+00   1.1243915E+00     T     F
#                          Ref_Ele    Start_Ele   Ele                    Meas           Model          Design | Opt  Plot
#                                                                                                             |   Useit
# ------------------------
# Tao> show var cell_quads
#   Variable                   Slave Parameters           Meas         Model        Design  Useit_opt
#   cell_quads[1]              1,10[K1]               0.0000E+00    1.0000E-01    1.0000E-01       F
#   cell_quads[2]              5,6[K1]                0.0000E+00   -1.0000E-01   -1.0000E-01       F
#   Variable                   Slave Parameters           Meas         Model        Design  Useit_opt
# ---------------------
# Tao> alias opt run lm
# -------------------------------------------------------------------
# Tao> set branch 0 geometry = open ! avoid re-computing trajectories
# --------
# Tao> opt
# Optimizing with: lm
# Type ``.'' to stop the optimizer before it's finished.
# [INFO] tao_dmodel_dvar_calc:
#     Remaking dModel_dVar derivative matrix.
#     This may take a while...
#
#   Cycle      Merit    A_lambda
#     1    2.9755E-03   1.00E-04
#     2    2.6600E-04   1.00E-05
#     3    2.9411E-05   1.00E-06
#     4    3.4159E-06   1.00E-07
#     5    4.0232E-07   1.00E-08
#     6    4.7596E-08   1.00E-09
#     7    5.6393E-09   1.00E-10
#     8    6.6851E-10   1.00E-11
#     9    7.9261E-11   1.00E-12
#    10    9.3982E-12   1.00E-13
#    11    1.1144E-12   1.00E-14
#    12    1.3214E-13   1.00E-15
#    13    1.5668E-14   1.00E-16
#    14    1.8579E-15   1.00E-17
#    15    2.2030E-16   1.00E-18
#    16    2.6122E-17   1.00E-19
#    17    3.0975E-18   1.00E-20
#    18    3.6728E-19   1.00E-21
#    19    4.3550E-20   1.00E-22
#    20    5.1641E-21   1.00E-23
# Written: var1.out
#    21    5.1641E-21   0.00E+00
# --------------------
# Tao> show data phase
# Data name: phase.1
#                                                                                                             |   Useit
#                          Ref_Ele    Start_Ele   Ele                    Meas           Model          Design | Opt  Plot
#     1  phase.a <target>  BEGINNING              QF_STRAIGHT   1.0471976E+00   1.0471976E+00   1.1691740E+00     T     F
#     2  phase.b <target>  BEGINNING              QF_STRAIGHT   1.0471976E+00   1.0471976E+00   1.1243915E+00     T     F
#                          Ref_Ele    Start_Ele   Ele                    Meas           Model          Design | Opt  Plot
#                                                                                                             |   Useit

# %% [markdown]
# Horray! Okay, let's apply these parameters to all straight cells, then move on to the bending and DS cells.
#
# <!-- tao.cmd('show var quads') -->

# %%
k1_f = tao.cmd('pipe var cell_quads[1]')[0].split(';')[-1]
k1_d = tao.cmd('pipe var cell_quads[2]')[0].split(';')[-1]

tao.cmd(f'set ele QF_S* k1 = {k1_f}')
tao.cmd(f'set ele QD_S* k1 = {k1_d}')

# --- #

opt_target = DS_cell_ix

set_data_ix(opt_target)
status1 = create_var(opt_target, 'QF_DS', var = 'cell_quads[1]') 
status2 = create_var(opt_target, 'QD_DS', var = 'cell_quads[2]')

assert status1
assert status2

display(tao.cmd('opt'))
display(tao.show('data phase'))


k1_f = tao.cmd('pipe var cell_quads[1]')[0].split(';')[-1]
k1_d = tao.cmd('pipe var cell_quads[2]')[0].split(';')[-1]

tao.cmd(f'set ele QF_DS k1 = {k1_f}')
tao.cmd(f'set ele QD_DS k1 = {k1_d}');
# Out:
# ['Optimizing with: lm',
#  "Type ``.'' to stop the optimizer before it's finished.",
#  '[INFO] tao_dmodel_dvar_calc:',
#  '    Remaking dModel_dVar derivative matrix.',
#  '    This may take a while...',
#  '',
#  '  Cycle      Merit    A_lambda',
#  '    1    1.1124E+01   2.00E-03',
#  '    2    1.1124E+01   4.00E-03',
#  '    3    1.1124E+01   8.00E-03',
#  '    4    1.1124E+01   1.60E-02',
#  '    5    1.1124E+01   3.20E-02',
#  '    6    1.1124E+01   6.40E-02',
#  '    7    1.1124E+01   1.28E-01',
#  '    8    1.1124E+01   2.56E-01',
#  '    9    1.1124E+01   5.12E-01',
#  '   10    1.1124E+01   1.02E+00',
#  '   11    1.1124E+01   2.05E+00',
#  '   12    1.1124E+01   4.10E+00',
#  '   13    1.0751E+01   4.10E-01',
#  '   14    1.0751E+01   8.19E-01',
#  '   15    1.0751E+01   1.64E+00',
#  '   16    1.0751E+01   3.28E+00',
#  '   17    1.0751E+01   6.55E+00',
#  '   18    1.0588E+01   6.55E-01',
#  '   19    1.0588E+01   1.31E+00',
#  '   20    1.0588E+01   2.62E+00',
#  'Written: var1.out',
#  '   21    1.0588E+01   0.00E+00']
# ['Data name: phase.1',
#  '                                                                                                        |   Useit',
#  '                         Ref_Ele   Start_Ele   Ele                 Meas           Model          Design | Opt  Plot',
#  '    1  phase.a <target>  M                     QF_DS      1.0471976E+00   6.2169080E-02   1.3389183E+00     T     F',
#  '    2  phase.b <target>  M                     QF_DS      1.0471976E+00   1.3447914E+00   1.1243915E+00     T     F',
#  '                         Ref_Ele   Start_Ele   Ele                 Meas           Model          Design | Opt  Plot',
#  '                                                                                                        |   Useit']

# %%
opt_target = Race_cell_ix

set_data_ix(opt_target)
status1 = create_var(opt_target, 'QF_RACETRACK', var = 'cell_quads[1]')
status2 = create_var(opt_target, 'QD_RACETRACK', var = 'cell_quads[2]')

assert status1
assert status2

display(tao.cmd('opt'))
display(tao.show('data phase'))


k1_f = tao.cmd('pipe var cell_quads[1]')[0].split(';')[-1]
k1_d = tao.cmd('pipe var cell_quads[2]')[0].split(';')[-1]

tao.cmd(f'set ele QF_RACETRACK k1 = {k1_f}')
tao.cmd(f'set ele QD_RACETRACK k1 = {k1_d}');
# Out:
# ['Optimizing with: lm',
#  "Type ``.'' to stop the optimizer before it's finished.",
#  '[INFO] tao_dmodel_dvar_calc:',
#  '    Remaking dModel_dVar derivative matrix.',
#  '    This may take a while...',
#  '',
#  '  Cycle      Merit    A_lambda',
#  '    1    6.8851E-03   1.00E-04',
#  '    2    6.2370E-04   1.00E-05',
#  '    3    5.3720E-05   1.00E-06',
#  '    4    4.7318E-06   1.00E-07',
#  '    5    4.1408E-07   1.00E-08',
#  '    6    3.6310E-08   1.00E-09',
#  '    7    3.1821E-09   1.00E-10',
#  '    8    2.7891E-10   1.00E-11',
#  '    9    2.4445E-11   1.00E-12',
#  '   10    2.1426E-12   1.00E-13',
#  '   11    1.8779E-13   1.00E-14',
#  '   12    1.6459E-14   1.00E-15',
#  '   13    1.4426E-15   1.00E-16',
#  '   14    1.2644E-16   1.00E-17',
#  '   15    1.1082E-17   1.00E-18',
#  '   16    9.7133E-19   1.00E-19',
#  '   17    8.5128E-20   1.00E-20',
#  '   18    7.4605E-21   1.00E-21',
#  '   19    6.5413E-22   1.00E-22',
#  '   20    5.7350E-23   1.00E-23',
#  'Written: var1.out',
#  '   21    5.7350E-23   0.00E+00']
# ['Data name: phase.1',
#  '                                                                                                            |   Useit',
#  '                         Ref_Ele   Start_Ele   Ele                     Meas           Model          Design | Opt  Plot',
#  '    1  phase.a <target>  QF_DS                 QF_RACETRACK   1.0471976E+00   1.0471976E+00   1.3698148E+00     T     F',
#  '    2  phase.b <target>  QF_DS                 QF_RACETRACK   1.0471976E+00   1.0471976E+00   1.1243915E+00     T     F',
#  '                         Ref_Ele   Start_Ele   Ele                     Meas           Model          Design | Opt  Plot',
#  '                                                                                                            |   Useit']

# %% [markdown]
# I did have to rerun the optimization a few times to get my merit all the way down. Here is the final result:

# %%
tao.cmd('set branch 0 geometry = closed')
tao.plot(['phase', 'eta'])

# %% [markdown]
# Which, uhh, still isn't quite right?
